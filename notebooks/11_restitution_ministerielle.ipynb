# %% [markdown]
# # 11 - Restitution ministérielle
#
# Cette étape traduit les résultats scientifiques en langage décisionnel.
# L’objectif est de produire une note claire pour les décideurs publics.

# %%
import pandas as pd

note = pd.DataFrame({
    'Section': [
        'Problématique',
        'Méthodologie',
        'Résultats',
        'Interprétation',
        'Recommandations'
    ],
    'Contenu': [
        'Mesurer les écarts de maîtrise en lecture entre élèves favorisés et défavorisés.',
        'Sondage stratifié, régression, psychométrie et modèles d’analyse.',
        'Des écarts sociaux et territoriaux persistent, avec un impact fort du retard.',
        'Le contexte socio-économique demeure un déterminant majeur des performances.',
        'Renforcer le ciblage territorial, le soutien précoces et l’accompagnement des élèves en difficulté.'
    ]
})

print(note.to_string(index=False))
# Out:
#         Section                                                                                             Contenu
#   Problématique                    Mesurer les écarts de maîtrise en lecture entre élèves favorisés et défavorisés.
#    Méthodologie                                   Sondage stratifié, régression, psychométrie et modèles d’analyse.
#       Résultats                       Des écarts sociaux et territoriaux persistent, avec un impact fort du retard.
#  Interprétation                        Le contexte socio-économique demeure un déterminant majeur des performances.
# Recommandations Renforcer le ciblage territorial, le soutien précoces et l’accompagnement des élèves en difficulté.
