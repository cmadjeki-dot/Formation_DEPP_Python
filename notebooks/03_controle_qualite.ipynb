# %% [markdown]
# # 03 - Contrôle qualité statistique
#
# Avant toute analyse, il faut vérifier :
# - présence de doublons ;
# - valeurs manquantes ;
# - cohérence des types ;
# - valeurs aberrantes.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.data.loader import load_csv, data_path
from src.quality.check import duplicate_count, missing_values_report, summarize_quality

df = load_csv(data_path('data', 'raw', 'etude_lecture_6e.csv'))
print('Doublons :', duplicate_count(df))
print('\nValeurs manquantes par variable :')
print(missing_values_report(df))
print('\nSynthèse qualité :')
print(summarize_quality(df))

score = df['score_lecture']
print('\nDistribution du score lecture :')
print(score.describe())
print('Valeurs aberrantes (score < 0 ou > 100) :', int(((score < 0) | (score > 100)).sum()))
# Out:
# Doublons : 0
#
# Valeurs manquantes par variable :
# id_eleve          0
# sexe              0
# pcs               0
# retard            0
# academie          0
# type_etab         0
# ressources_num    0
# age               0
# score_lecture     0
# dtype: int64
#
# Synthèse qualité :
#          variable  n_missing  pct_missing  n_unique    dtype
# 0        id_eleve          0          0.0     15000    int64
# 1            sexe          0          0.0         2   object
# 2             pcs          0          0.0         6   object
# 3          retard          0          0.0         2    int64
# 4        academie          0          0.0         8   object
# 5       type_etab          0          0.0         2   object
# 6  ressources_num          0          0.0     15000  float64
# 7             age          0          0.0         4    int64
# 8   score_lecture          0          0.0      5425  float64
#
# Distribution du score lecture :
# count    15000.000000
# ...
