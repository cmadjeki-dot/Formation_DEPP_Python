# %% [markdown]
# # 01 - Génération des données
#
# Dans cette étape, on simule la base ministérielle des élèves de 6e.
# L’objectif est de produire une base réaliste, avec variables de contexte,
# variables de performance et structure de sondage.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.data.simulate_depp import generate_student_dataset
from src.data.loader import save_csv, data_path

data = generate_student_dataset(n_students=15000, seed=42)
print(data.head())
print('Taille de la base :', data.shape)

output_path = data_path('data', 'raw', 'etude_lecture_6e.csv')
save_csv(data, output_path)
print('Base exportée vers :', output_path)
# Out:
#    id_eleve sexe                         pcs  retard   academie type_etab  \
# 0         1    F                     Ouvrier       0      Paris     Prive
# 1         2    M  Professions_intermediaires       0  Marseille    Public
# 2         3    M  Professions_intermediaires       0   Bordeaux     Prive
# 3         4    F                 Agriculteur       0   Toulouse     Prive
# 4         5    F  Professions_intermediaires       0       Lyon     Prive
#
#    ressources_num  age  score_lecture
# 0        0.374707   12          60.68
# 1        0.488816   10          88.52
# 2        0.591353   10          79.76
# 3        0.696321   11          78.79
# 4        0.686939   10          71.75
# Taille de la base : (15000, 9)
# Base exportée vers : C:\Users\admin\Desktop\Formation_DEPP_Python\src\data\raw\etude_lecture_6e.csv
