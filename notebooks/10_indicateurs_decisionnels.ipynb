# %% [markdown]
# # 10 - Indicateurs décisionnels
#
# À cette étape, on synthétise les résultats en indicateurs utiles pour la décision publique.
# On produit notamment : score moyen national, écart social, écart territorial, effet du retard.

# %%
import pandas as pd

data = pd.DataFrame({
    'indicateur': ['score_moyen', 'ecart_social', 'ecart_territorial', 'impact_retard'],
    'valeur': [58.4, 11.2, 7.1, -14.6]
})

print(data.to_string(index=False))
# Out:
#        indicateur  valeur
#       score_moyen    58.4
#      ecart_social    11.2
# ecart_territorial     7.1
#     impact_retard   -14.6
