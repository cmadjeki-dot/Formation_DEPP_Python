# %% [markdown]
# # 08 - Analyse longitudinale
#
# On suit l’évolution des performances en lecture dans le temps.
# Dans le cadre DEPP, cela permet de mesurer les gains ou pertes sur plusieurs cohortes.

# %%
import pandas as pd
import numpy as np

n = 500
rng = np.random.default_rng(42)
dates = pd.date_range('2022-01-01', periods=4, freq='Y')
df = pd.DataFrame({
    'annee': dates.year,
    'score_lecture': [56, 58, 61, 64]
})

print('Évolution du score moyen :')
print(df)
print('\nTendance moyenne :', round(df['score_lecture'].diff().mean(), 2))
# Out:
# Évolution du score moyen :
#    annee  score_lecture
# 0   2022             56
# 1   2023             58
# 2   2024             61
# 3   2025             64
#
# Tendance moyenne : 2.67
# C:\Users\admin\AppData\Local\Temp\ipykernel_9236\745221026.py:6: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range('2022-01-01', periods=4, freq='Y')
