# %% [markdown]
# # 00 - Cadrage du projet
#
# Ce notebook introduit le projet, les objectifs, les données et l'organisation du travail.

# %%
import pandas as pd
import numpy as np

print('Projet DEPP - environnement prêt')
