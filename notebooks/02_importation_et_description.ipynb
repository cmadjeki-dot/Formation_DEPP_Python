# %% [markdown]
# # 02 - Importation et description
#
# On réimporte la base simulée et on décrit les variables clés.
# On vérifie le format, les types et la structure d’ensemble avant le contrôle qualité.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.data.loader import load_csv, data_path

    path = data_path('data', 'raw', 'etude_lecture_6e.csv')
df = load_csv(path)
print('Chemin de la base :', path)
print('Dimensions :', df.shape)
print('\nTypes de colonnes :')
print(df.dtypes)
print('\nAperçu :')
print(df.head())
print('\nStatistiques descriptives :')
print(df.describe(include='all').T)
# Out:
#   Cell In[2], line 14
#     print('
#           ^
# SyntaxError: unterminated string literal (detected at line 14)
